# %% [markdown]
# # Trading Strategies
#
# Let's start with a classic and simple trading strategy: the moving average crossover. The idea behind this strategy is to buy a stock when its fast simple moving average (SMA) crosses above its slow SMA and to short it when the fast SMA crosses below the slow SMA.
#
# Let's start with our imports in the cell below, and preparing our data frame in the cell below that.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %% [markdown]
# This time we'll fetch our data directly from yfinance.

# %%
# 直接从Yahoo Finance上抽取数据
import yfinance as yf

df = yf.download("JPM", start ="2025-01-01")
# JPM是jp morgan的ticker symbol,只写这个就是他们的所有时间的所有数据
# 逗号加start和end可以截取部分时间（只说start就是抓取最新的）
df
# 可以发现每个数据名字旁边都有ticker名字，因为这个方法可以一次性下载非常多的ticker的数据库
# Out:
# /tmp/ipykernel_6326/3674797558.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("JPM", start ="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             JPM         JPM         JPM         JPM       JPM
# Date
# 2025-01-02  237.305161  240.548330  236.761333  238.214828   9220900
# 2025-01-03  240.548340  242.130380  237.562246  241.151491   9491100
# 2025-01-06  239.375565  244.185931  239.107213  242.208108   9917800
# 2025-01-07  241.681351  243.758552  239.425243  240.657657   8753400
# 2025-01-08  241.641602  242.754740  239.027697  241.263923   8675300
# ...                ...         ...         ...         ...       ...
# 2025-06-13  264.950012  267.019989  262.709991  265.079987   7098300
# 2025-06-16  270.359985  271.730011  266.850006  267.000000   8566000
# 2025-06-17  269.519989  270.589996  267.799988  268.170013   6739300
# 2025-06-18  273.959991  277.720001  269.720001  270.000000   9586400
# 2025-06-20  275.000000  277.299988  273.809998  275.570007  13943300
#
# [116 rows x 5 columns]

# %%
# 如果不想要这种“double level”的column命名方法以方便后面coding，可以：
df.columns = df.columns.droplevel(1)
# drop column名字的level 1就是drop JPM，如Close这种是level 0
df
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2025-01-02  237.305161  240.548330  236.761333  238.214828   9220900
# 2025-01-03  240.548340  242.130380  237.562246  241.151491   9491100
# 2025-01-06  239.375565  244.185931  239.107213  242.208108   9917800
# 2025-01-07  241.681351  243.758552  239.425243  240.657657   8753400
# 2025-01-08  241.641602  242.754740  239.027697  241.263923   8675300
# ...                ...         ...         ...         ...       ...
# 2025-06-13  264.950012  267.019989  262.709991  265.079987   7098300
# 2025-06-16  270.359985  271.730011  266.850006  267.000000   8566000
# 2025-06-17  269.519989  270.589996  267.799988  268.170013   6739300
# 2025-06-18  273.959991  277.720001  269.720001  270.000000   9586400
# 2025-06-20  275.000000  277.299988  273.809998  275.570007  13943300
#
# [116 rows x 5 columns]

# %% [markdown]
# ## Compute and Plot SMAs
#
# Before we can implement our strategy, we need to calculate the fast (short-term) and slow (long-term) SMAs. For this example, we'll use 20-day and 50-day SMAs.

# %%
# trading strategy是a strategy of buying and selling at different points of a period

# 先看最classic的strategy：Moving Average Crossover Strategy
# 用两条closing做的SMA：1. Fast MA：较短周期的平均线（如10日），对价格变化更敏感; 2. Slow M：较长周期的平均线（如50日），对趋势反应较慢。
# Golden Cross (upswing coming, buy):当快线（短期SMA）上穿慢线（长期SMA）;Death Cross(failing coming, sell):快线下穿慢线
# 进阶版：当前价格(如closing) > 两条均线 → 趋势更强；当前价格突然跌破慢线 → 风险提示

# 创建一个consistently used in other places的variable叫创建一个constant，名字用大写
FAST = 5
SLOW = 10
# 以上就是建立了快慢线的时长constant，单位是day；这样非常方便后期做实验更改，直接改这两个就行了

df["FastMA"] = df.Close.rolling(FAST).mean()
df["SlowMA"] = df.Close.rolling(SLOW).mean()
df
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-01-02  237.305161  240.548330  236.761333  238.214828   9220900
# 2025-01-03  240.548340  242.130380  237.562246  241.151491   9491100
# 2025-01-06  239.375565  244.185931  239.107213  242.208108   9917800
# 2025-01-07  241.681351  243.758552  239.425243  240.657657   8753400
# 2025-01-08  241.641602  242.754740  239.027697  241.263923   8675300
# ...                ...         ...         ...         ...       ...
# 2025-06-13  264.950012  267.019989  262.709991  265.079987   7098300
# 2025-06-16  270.359985  271.730011  266.850006  267.000000   8566000
# 2025-06-17  269.519989  270.589996  267.799988  268.170013   6739300
# 2025-06-18  273.959991  277.720001  269.720001  270.000000   9586400
# 2025-06-20  275.000000  277.299988  273.809998  275.570007  13943300
#
# Price           FastMA      SlowMA
# Date
# 2025-01-02         NaN         NaN
# 2025-01-03         NaN         NaN
# 2025-01-06         NaN         NaN
# 2025-01-07         NaN         NaN
# 2025-01-08  240.110403         NaN
# ...                ...         ...
# 2025-06-13  267.335999  265.951001
# 2025-06-16  268.059998  266.520999
# 2025-06-17  268.243994  266.845999
# 2025-06-18  269.405994  267.819998
# 2025-06-20  270.757996  269.124997
#
# [116 rows x 7 columns]

# %% [markdown]
# Remember we'll have a window-length of NaNs in our data frame. This is because we don't have enough data points to calculate an N-day moving average until the Nth day.
# Let's plot the closing price with the SMAs to visually inspect the crossover points.

# %%
# basic plot needs: figure, size, title, xlable, ylable, legend 
plt.plot(df.Close, label = "Close")
plt.plot(df.SlowMA, label = "Slow MA", color = "darkseagreen")
plt.plot(df.FastMA, label="Fast MA", color = "royalblue")
plt.legend()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %% [markdown]
# ## The Crossover
#
# To determine the crossover points, we will create a new column signal which will contain 1 for buy signals (when the fast SMA is above the slow SMA) and -1 for sell signals. Because we are in a *wait* position while we *wait* for the 200-day SMA to kick-in, we'll fill the Signal column with 0 for those rows. We'll use `where()` for both of these.

# %%
# 想要知道按这个strategy每天应该做什么？1代表buy，-1代表sell
df["Signal"] = np.where(df.FastMA > df.SlowMA, 1, -1)
df
# 看一下结果，会发现在MA都还没数据的时候，signal也给了-1，这是根据where公式出来的，不是根据实际情况做的判断；我们要去掉他们
df.Signal = np.where(df.SlowMA.isna(), 0, df.Signal)
# 以上的公式就可以保证，当SlowMA（isna更多点）还是missing的时候，signal写0，不然就保持signal原数据
df
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-01-02  237.305161  240.548330  236.761333  238.214828   9220900
# 2025-01-03  240.548340  242.130380  237.562246  241.151491   9491100
# 2025-01-06  239.375565  244.185931  239.107213  242.208108   9917800
# 2025-01-07  241.681351  243.758552  239.425243  240.657657   8753400
# 2025-01-08  241.641602  242.754740  239.027697  241.263923   8675300
# ...                ...         ...         ...         ...       ...
# 2025-06-13  264.950012  267.019989  262.709991  265.079987   7098300
# 2025-06-16  270.359985  271.730011  266.850006  267.000000   8566000
# 2025-06-17  269.519989  270.589996  267.799988  268.170013   6739300
# 2025-06-18  273.959991  277.720001  269.720001  270.000000   9586400
# 2025-06-20  275.000000  277.299988  273.809998  275.570007  13943300
#
# Price           FastMA      SlowMA  Signal
# Date
# 2025-01-02         NaN         NaN       0
# 2025-01-03         NaN         NaN       0
# 2025-01-06         NaN         NaN       0
# 2025-01-07         NaN         NaN       0
# 2025-01-08  240.110403         NaN       0
# ...                ...         ...     ...
# 2025-06-13  267.335999  265.951001       1
# 2025-06-16  268.059998  266.520999       1
# 2025-06-17  268.243994  266.845999       1
# 2025-06-18  269.405994  267.819998       1
# 2025-06-20  270.757996  269.124997       1
#
# [116 rows x 8 columns]

# %% [markdown]
# ### Exercise: Blink and you'll miss it
#
# Can you identify on which dates we had a crossover?

# %%
# 用diff来找buy和sell的crossover，如果有crossover会有diff == 2 or -2； | is for or
df [(df.Signal.diff() == 2) | (df.Signal.diff() == -2) ]
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-02-21  262.622375  267.552033  261.230952  266.677416  12835600
# 2025-03-20  237.546814  240.279979  234.754019  235.111816   8328500
# 2025-04-02  244.315140  245.736378  239.981830  240.120973   7758800
# 2025-04-14  234.720001  239.779999  233.630005  237.100006  13017800
# 2025-05-23  260.709991  261.989990  256.000000  256.809998   6671800
# 2025-06-02  264.660004  265.029999  261.899994  263.019989   6011200
#
# Price           FastMA      SlowMA  Signal
# Date
# 2025-02-21  271.692505  272.365359      -1
# 2025-03-20  234.447906  232.188824       1
# 2025-04-02  243.649240  244.157111      -1
# 2025-04-14  229.847998  228.773351       1
# 2025-05-23  262.596002  263.673001      -1
# 2025-06-02  264.362000  263.479001       1

# %% [markdown]
# ## Backtesting
#
# Backtesting is the process of testing a trading strategy on relevant historical data. We can calculate how it would have performed, had it been applied in the past. The simplest backtest calculates the returns that would have been realised if the strategy was implemented.
#
# First, we create a new column with the signal from the previous day. When we backtest, we have to imagine we're trading in real time. Since our signals are based on close prices, we won't be able to act on them until the following day when the market re-opens. Failing to do this is called *look-ahead bias*.

# %%
# 测试strategy有用不：用用了strategy之后在crosspoint的return有多少来测
# 测的时候要注意look-ahead bias；因为买卖信号是基于closing生成的，所以当天不可能执行信号，必须等到第二天开盘时才能根据它进行操作
# 所以要用前一天的signal，要shift一下（当然也可以创建一个新的column position）
df.Signal = df.Signal.shift()

# %% [markdown]
# Next we calculate the market daily returns normally using `pct_change()`. We then calculate our strategy returns by multiplying our buy/sell position with the market returns. Here is how it works:
#
# - On days when the market gains (+ market return)
#     - In the buy position (+) , our strategy gains
#     - In the sell position (-), our strategy loses
# - On days when the market loses (- market return)
#     - In the buy position (+), our strategy loses
#     - In the sell position (-), our strategy gains

# %%
df["Returns"] = df.Close.pct_change()
df["Strategy"] = df.Returns * df.Signal
# 以上的returns和signal相乘的原理：
# + returns, + strategy = + effect
# + returns, - strategy = - effect
# - returns, + strategy = - effect
# - returns, - strategy = + effect
# 所以，直接看+还是- effect就知道strategy的正确性
df
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-01-02  237.305161  240.548330  236.761333  238.214828   9220900
# 2025-01-03  240.548340  242.130380  237.562246  241.151491   9491100
# 2025-01-06  239.375565  244.185931  239.107213  242.208108   9917800
# 2025-01-07  241.681351  243.758552  239.425243  240.657657   8753400
# 2025-01-08  241.641602  242.754740  239.027697  241.263923   8675300
# ...                ...         ...         ...         ...       ...
# 2025-06-13  264.950012  267.019989  262.709991  265.079987   7098300
# 2025-06-16  270.359985  271.730011  266.850006  267.000000   8566000
# 2025-06-17  269.519989  270.589996  267.799988  268.170013   6739300
# 2025-06-18  273.959991  277.720001  269.720001  270.000000   9586400
# 2025-06-20  275.000000  277.299988  273.809998  275.570007  13943300
#
# Price           FastMA      SlowMA  Signal   Returns  Strategy
# Date
# 2025-01-02         NaN         NaN     NaN       NaN       NaN
# 2025-01-03         NaN         NaN     0.0  0.013667  0.000000
# 2025-01-06         NaN         NaN     0.0 -0.004875 -0.000000
# 2025-01-07         NaN         NaN     0.0  0.009633  0.000000
# 2025-01-08  240.110403         NaN     0.0 -0.000164 -0.000000
# ...                ...         ...     ...       ...       ...
# 2025-06-13  267.335999  265.951001     1.0 -0.012265 -0.012265
# 2025-06-16  268.059998  266.520999     1.0  0.020419  0.020419
# 2025-06-17  268.243994  266.845999     1.0 -0.003107 -0.003107
# 2025-06-18  269.405994  267.819998     1.0  0.016474  0.016474
# 2025-06-20  270.757996  269.124997     1.0  0.003796  0.003796
#
# [116 rows x 10 columns]

# %% [markdown]
# To determine if our strategy would profit or lose, we can calculate the cumulative returns of our strategy for the period. We can then compare it to a *buy & hold* strategy (where we buy at the start of the period and sell at the end), which is represented as the cumulative market returns.

# %%
# 如何检查总的来讲这个moving average crossover strategy有用不？用cumulative return来算
df["MACS"] = (1 + df.Strategy).cumprod() - 1
# 并对比简单的buy&hold strategy(一开始就买，到最后卖)
df["BuyHold"] = (1 + df.Returns).cumprod() - 1
# 然后看看最后的结果，也就是看最后的final数字：
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-06-13  264.950012  267.019989  262.709991  265.079987   7098300
# 2025-06-16  270.359985  271.730011  266.850006  267.000000   8566000
# 2025-06-17  269.519989  270.589996  267.799988  268.170013   6739300
# 2025-06-18  273.959991  277.720001  269.720001  270.000000   9586400
# 2025-06-20  275.000000  277.299988  273.809998  275.570007  13943300
#
# Price           FastMA      SlowMA  Signal   Returns  Strategy      MACS  \
# Date
# 2025-06-13  267.335999  265.951001     1.0 -0.012265 -0.012265  0.310885
# 2025-06-16  268.059998  266.520999     1.0  0.020419  0.020419  0.337651
# 2025-06-17  268.243994  266.845999     1.0 -0.003107 -0.003107  0.333495
# 2025-06-18  269.405994  267.819998     1.0  0.016474  0.016474  0.355463
# 2025-06-20  270.757996  269.124997     1.0  0.003796  0.003796  0.360609
#
# Price        BuyHold
# Date
# 2025-06-13  0.116495
# 2025-06-16  0.139292
# 2025-06-17  0.135753
# 2025-06-18  0.154463
# 2025-06-20  0.158845

# %% [markdown]
# Let's plot these for a visual representation.

# %%
plt.figure(figsize=(8, 3))
plt.title("Strategy vs Benchmark (JPM)")
plt.xlabel("Date")
plt.ylabel("Return")
plt.plot(df.BuyHold, label = "Buy & Hold")
plt.plot(df.MACS, label="Moving Average Xover")
plt.legend()
plt.tight_layout()
